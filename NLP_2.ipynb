# %% [markdown]
# NLP BASED CHATBOT

# %%
#TOKENIZATION
from nltk.tokenize import word_tokenize
#STOPWORDS LIST
from nltk.corpus import stopwords
#stemming
from nltk.stem import PorterStemmer
#lemmatization
from nltk.stem import WordNetLemmatizer
import string
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
import numpy as np
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
training_data=[
    ("hello","greet"),
    ("hi","greet"),
    ("hello there","greet"),
    ("hey","greet"),
    ("good morning","greet"),
    ("good afternoon","greet"),
    ("good evening","greet"),
    ("what is the weather today","weather"),
    ("what is the temperature today","weather"),
    ("what is the humidity today","weather"),
    ("is it raining","weather"),
    ("open google","open_web"),
    ("open youtube","open_web"),
    ("open facebook","open_web"),
    ("go to google","open_web"),
    ("go to youtube","open_web"),
    ("go to facebook","open_web"),
    ("bye","exit"),
    ("goodbye","exit"),
    ("see you later","exit"),
    ("bye bye","exit"),
    ("quit","exit")
]

# %%
sentences=[]  #features/ X
labels=[]   #features/ Y
for text, intent in training_data:
    sentences.append(text)
    labels.append(intent)

# %%
def preprocess_text(documents):
    english_stopwords = stopwords.words("english")
    punctuations = string.punctuation
    cleaned_documents = []
    for doc in documents:
        # Step-1 : Lowercase
        raw_text = doc.lower()
        print("After lowercase: ",raw_text)

        tokens = word_tokenize(raw_text)
        print("Tokens:",tokens)

        filtered_tokens = []
        for word in tokens:
            if word not in english_stopwords:
                filtered_tokens.append(word)

        print("Filtered Tokens :",filtered_tokens)

        clean_tokens = [word for word in filtered_tokens if word not in punctuations]
        print("After removing punctuations:",clean_tokens)

        lemmatized_words = []
        wnet = WordNetLemmatizer()
        for word in clean_tokens:
            lemmatized_words.append(wnet.lemmatize(word,"v"))

        print("After Lemmatization :",lemmatized_words)

        final_tokens = []
        for word in lemmatized_words:
            if word.isalpha():
                final_tokens.append(word)

        print("Final Tokens:",final_tokens)

        cleaned_text = " ".join(final_tokens)
        print("Cleaned Text:",cleaned_text)

        cleaned_documents.append(cleaned_text)
        print("="*50)
    return cleaned_documents

cleaned_sentences = preprocess_text(sentences)
# Out:
# After lowercase:  hello
# Tokens: ['hello']
# Filtered Tokens : ['hello']
# After removing punctuations: ['hello']
# After Lemmatization : ['hello']
# Final Tokens: ['hello']
# Cleaned Text: hello
# ==================================================
# After lowercase:  hi
# Tokens: ['hi']
# Filtered Tokens : ['hi']
# After removing punctuations: ['hi']
# After Lemmatization : ['hi']
# Final Tokens: ['hi']
# Cleaned Text: hi
# ==================================================
# After lowercase:  hello there
# Tokens: ['hello', 'there']
# Filtered Tokens : ['hello']
# After removing punctuations: ['hello']
# After Lemmatization : ['hello']
# Final Tokens: ['hello']
# Cleaned Text: hello
# ==================================================
# After lowercase:  hey
# Tokens: ['hey']
# Filtered Tokens : ['hey']
# After removing punctuations: ['hey']
# After Lemmatization : ['hey']
# Final Tokens: ['hey']
# Cleaned Text: hey
# ==================================================
# After lowercase:  good morning
# Tokens: ['good', 'morning']
# Filtered Tokens : ['good', 'morning']
# After removing punctuations: ['good', 'morning']
# After Lemmatization : ['good', 'morning']
# Final Tokens: ['good', 'morning']
# Cleaned Text: good morning
# ==================================================
# After lowercase:  good afternoon
# Tokens: ['good', 'afternoon']
# Filtered Tokens : ['good', 'afternoon']
# After removing punctuations: ['good', 'afternoon']
# After Lemmatization : ['good', 'afternoon']
# Final Tokens: ['good', 'afternoon']
# Cleaned Text: good afternoon
# ==================================================
# After lowercase:  good evening
# Tokens: ['good', 'evening']
# Filtered Tokens : ['good', 'evening']
# After removing punctuations: ['good', 'evening']
# After Lemmatization : ['good', 'even']
# Final Tokens: ['good', 'even']
# Cleaned Text: good even
# ==================================================
# After lowercase:  what is the weather today
# Tokens: ['what', 'is', 'the', 'weather', 'today']
# Filtered Tokens : ['weather', 'today']
# After removing punctuations: ['weather', 'today']
# After Lemmatization : ['weather', 'today']
# Final Tokens: ['weather', 'today']
# Cleaned Text: weather today
# ==================================================
# After lowercase:  what is the temperature today
# Tokens: ['what', 'is', 'the', 'temperature', 'today']
# Filtered Tokens : ['temperature', 'today']
# After removing punctuations: ['temperature', 'today']
# After Lemmatization : ['temperature', 'today']
# Final Tokens: ['temperature', 'today']
# Cleaned Text: temperature today
# ==================================================
# After lowercase:  what is the humidity today
# Tokens: ['what', 'is', 'the', 'humidity', 'today']
# Filtered Tokens : ['humidity', 'today']
# After removing punctuations: ['humidity', 'today']
# After Lemmatization : ['humidity', 'today']
# Final Tokens: ['humidity', 'today']
# Cleaned Text: humidity today
# ==================================================
# After lowercase:  is it raining
# Tokens: ['is', 'it', 'raining']
# Filtered Tokens : ['raining']
# After removing punctuations: ['raining']
# After Lemmatization : ['rain']
# Final Tokens: ['rain']
# Cleaned Text: rain
# ==================================================
# After lowercase:  open google
# Tokens: ['open', 'google']
# Filtered Tokens : ['open', 'google']
# After removing punctuations: ['open', 'google']
# After Lemmatization : ['open', 'google']
# Final Tokens: ['open', 'google']
# Cleaned Text: open google
# ==================================================
# After lowercase:  open youtube
# Tokens: ['open', 'youtube']
# Filtered Tokens : ['open', 'youtube']
# After removing punctuations: ['open', 'youtube']
# After Lemmatization : ['open', 'youtube']
# Final Tokens: ['open', 'youtube']
# Cleaned Text: open youtube
# ==================================================
# After lowercase:  open facebook
# Tokens: ['open', 'facebook']
# Filtered Tokens : ['open', 'facebook']
# After removing punctuations: ['open', 'facebook']
# After Lemmatization : ['open', 'facebook']
# Final Tokens: ['open', 'facebook']
# Cleaned Text: open facebook
# ==================================================
# After lowercase:  go to google
# Tokens: ['go', 'to', 'google']
# Filtered Tokens : ['go', 'google']
# After removing punctuations: ['go', 'google']
# After Lemmatization : ['go', 'google']
# Final Tokens: ['go', 'google']
# Cleaned Text: go google
# ==================================================
# After lowercase:  go to youtube
# Tokens: ['go', 'to', 'youtube']
# Filtered Tokens : ['go', 'youtube']
# After removing punctuations: ['go', 'youtube']
# After Lemmatization : ['go', 'youtube']
# Final Tokens: ['go', 'youtube']
# Cleaned Text: go youtube
# ==================================================
# After lowercase:  go to facebook
# Tokens: ['go', 'to', 'facebook']
# Filtered Tokens : ['go', 'facebook']
# After removing punctuations: ['go', 'facebook']
# After Lemmatization : ['go', 'facebook']
# Final Tokens: ['go', 'facebook']
# Cleaned Text: go facebook
# ==================================================
# After lowercase:  bye
# Tokens: ['bye']
# Filtered Tokens : ['bye']
# After removing punctuations: ['bye']
# After Lemmatization : ['bye']
# Final Tokens: ['bye']
# Cleaned Text: bye
# ==================================================
# After lowercase:  goodbye
# Tokens: ['goodbye']
# Filtered Tokens : ['goodbye']
# After removing punctuations: ['goodbye']
# After Lemmatization : ['goodbye']
# Final Tokens: ['goodbye']
# Cleaned Text: goodbye
# ==================================================
# After lowercase:  see you later
# Tokens: ['see', 'you', 'later']
# Filtered Tokens : ['see', 'later']
# After removing punctuations: ['see', 'later']
# After Lemmatization : ['see', 'later']
# Final Tokens: ['see', 'later']
# Cleaned Text: see later
# ==================================================
# After lowercase:  bye bye
# Tokens: ['bye', 'bye']
# Filtered Tokens : ['bye', 'bye']
# After removing punctuations: ['bye', 'bye']
# After Lemmatization : ['bye', 'bye']
# Final Tokens: ['bye', 'bye']
# Cleaned Text: bye bye
# ==================================================
# After lowercase:  quit
# Tokens: ['quit']
# Filtered Tokens : ['quit']
# After removing punctuations: ['quit']
# After Lemmatization : ['quit']
# Final Tokens: ['quit']
# Cleaned Text: quit
# ==================================================

# %%
#cleaned data
vectorizer=TfidfVectorizer()
X=vectorizer.fit_transform(cleaned_sentences)
model=LogisticRegression()
model.fit(X,labels)
# Out:
# LogisticRegression()

# %%
user_msg="open linked.in"
processed=preprocess_text([user_msg])
user_vector=vectorizer.transform(processed)
prediction=model.predict(user_vector)
print("Prediction is :",prediction)
# Out:
# After lowercase:  open linked.in
# Tokens: ['open', 'linked.in']
# Filtered Tokens : ['open', 'linked.in']
# After removing punctuations: ['open', 'linked.in']
# After Lemmatization : ['open', 'linked.in']
# Final Tokens: ['open']
# Cleaned Text: open
# ==================================================
# Prediction is : ['open_web']

# %%
import joblib

# %%
joblib.dump(model,"intent_model.pkl")
joblib.dump(vectorizer,"vectorizer.pkl")
# Out:
# ['vectorizer.pkl']
